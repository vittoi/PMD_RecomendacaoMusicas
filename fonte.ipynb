# %%
#Importação das bibliotecas.
from pyspark.sql import SparkSession
from pyspark.sql.window import Window
from pyspark.sql import functions as F
from pyspark.sql import Row as Row
from pyspark.sql.functions import col, split
import random
import pandas

spark = SparkSession.builder\
.appName('pmd22')\
.config("spark.jars","neo4j-connector-apache-spark_2.12-4.1.4_for_spark_3.jar")\
.getOrCreate()

# %%
#Lendo arquivo de usuarios
dat_usuarios = spark.read.load("B:\Faculdade\PMD\people_music.csv", format="csv", sep=",", inferSchema="true", header="true")

#Lendo arquivo de musicas
dat_music = spark.read.load("B:\Faculdade\PMD\music.csv", format="csv", sep=",", inferSchema="true", header="true")

dat_usuarios.show();
dat_music.show();
# Out:
# +---------+----------+-----------+-------------------+
# |id_person|      nome|  music_fav|             amigos|
# +---------+----------+-----------+-------------------+
# |        1|     Lorne|404,123,586|  1369,1744,406,223|
# |        2| Gavrielle| 384,41,550|  845,1134,1933,823|
# |        3|     Cordi|  52,391,39|    352,528,998,976|
# |        4|    Florie| 368,155,76|  736,1172,1584,443|
# |        5|    Odessa|536,590,507| 1783,1497,1915,425|
# |        6|    Sandie| 67,159,221|   234,506,704,1583|
# |        7|       Sam| 395,22,559| 1218,1870,1175,389|
# |        8|    Leanna|245,159,491|   628,1192,430,198|
# |        9|   Jasmina| 114,32,331| 1025,1227,691,1089|
# |       10|    Lolita|  190,33,47|   63,1417,929,1706|
# |       11|Anestassia|452,536,480|  768,628,1983,1258|
# |       12|   Chandra|244,123,166|      640,729,9,421|
# |       13|       Raf| 560,413,28|1727,1986,1741,1643|
# |       14|    Teddie|315,192,468|    135,120,1755,62|
# |       15|    Melina|  60,42,590| 1433,1997,863,1239|
# |       16|     Valli|110,339,590| 1868,826,1552,1549|
# |       17|      Emma|464,375,585| 1780,1155,356,1564|
# |       18|      Judy|  28,96,296|    637,87,706,1989|
# |       19|     Kenna|  415,358,5|  335,1511,921,1966|
# |       20|     Taffy|298,199,401|  212,226,1949,1896|
# +---------+----------+-----------+-------------------+
# only showing top 20 rows
#
# +--------------------+-------------------+----------------------+----------+---------------------------------------+---------------------------------------------------------------------+--------------------------------------------------------------------------+------------------------------------------------------+----------------------------------------------------------------------------+------------------------------------------------------------------+---------------------------------+-----------------------------------------------------------------+-------------------------------------------------------------------------+-------------------------------------------------------------+
# |               title|             artist|the genre of the track|      year|Beats.Per.Minute -The tempo of the song|Energy- The energy of a song - the higher the value the more energtic|Danceability - The higher the value the easier it is to dance to this song|Loudness/dB - The higher the value the louder the song|Liveness - The higher the value the more likely the song is a live recording|Valence - The higher the value the more positive mood for the song|Length - The duration of the song|Acousticness - The higher the value the more acoustic the song is|Speechiness - The higher the value the more spoken word the song contains|Popularity- The higher the value the more popular the song is|
# +--------------------+-------------------+----------------------+----------+---------------------------------------+---------------------------------------------------------------------+--------------------------------------------------------------------------+------------------------------------------------------+----------------------------------------------------------------------------+------------------------------------------------------------------+---------------------------------+-----------------------------------------------------------------+-------------------------------------------------------------------------+-------------------------------------------------------------+
# |                 Hey|        Soul Sister|                 Train|neo mellow|                                   2010|                                                                   97|                                                                        89|                                                    67|                                                                          -4|                                                                 8|                               80|                                                              217|                                                                       19|                                                            4|
# |Love The Way You Lie|             Eminem|       detroit hip hop|      2010|                                     87|                                                                   93|                                                                        75|                                                    -5|                                                                          52|                                                                64|                              263|                                                               24|                                                                       23|                                                           82|
# |             TiK ToK|              Kesha|             dance pop|      2010|                                    120|                                                                   84|                                                                        76|                                                    -3|                                                                          29|                                                                71|                              200|                                                               10|                                                                       14|                                                           80|
# |         Bad Romance|          Lady Gaga|             dance pop|      2010|                                    119|                                                                   92|                                                                        70|                                                    -4|                                                                           8|                                                                71|                              295|                                                                0|                                                                        4|                                                           79|
# |Just the Way You Are|         Bruno Mars|                   pop|      2010|                                    109|                                                                   84|                                                                        64|                                                    -5|                                                                           9|                                                                43|                              221|                                                                2|                                                                        4|                                                           78|
# |                Baby|      Justin Bieber|          canadian pop|      2010|                                     65|                                                                   86|                                                                        73|                                                    -5|                                                                          11|                                                                54|                              214|                                                                4|                                                                       14|                                                           77|
# |            Dynamite|          Taio Cruz|             dance pop|      2010|                                    120|                                                                   78|                                                                        75|                                                    -4|                                                                           4|                                                                82|                              203|                                                                0|                                                                        9|                                                           77|
# |             Secrets|        OneRepublic|             dance pop|      2010|                                    148|                                                                   76|                                                                        52|                                                    -6|                                                                          12|                                                                38|                              225|                                                                7|                                                                        4|                                                           77|
# |Empire State of M...|        Alicia Keys|               hip pop|      2010|                                     93|                                                                   37|                                                                        48|                                                    -8|                                                                          12|                                                                14|                              216|                                                               74|                                                                        3|                                                           76|
# |Only Girl (In The...|            Rihanna|         barbadian pop|      2010|                                    126|                                                                   72|                                                                        79|                                                    -4|                                                                           7|                                                                61|                              235|                                                               13|                                                                        4|                                                           73|
# |Club Can't Handle...|           Flo Rida|             dance pop|      2010|                                    128|                                                                   87|                                                                        62|                                                    -4|                                                                           6|                                                                47|                              235|                                                                3|                                                                        3|                                                           73|
# |           Marry You|         Bruno Mars|                   pop|      2010|                                    145|                                                                   83|                                                                        62|                                                    -5|                                                                          10|                                                                48|                              230|                                                               33|                                                                        4|                                                           73|
# |Cooler Than Me - ...|        Mike Posner|             dance pop|      2010|                                    130|                                                                   82|                                                                        77|                                                    -5|                                                                          70|                                                                63|                              213|                                                               18|                                                                        5|                                                           73|
# |           Telephone|          Lady Gaga|             dance pop|      2010|                                    122|                                                                   83|                                                                        83|                                                    -6|                                                                          11|                                                                71|                              221|                                                                1|                                                                        4|                                                           73|
# |           Like A G6|  Far East Movement|             dance pop|      2010|                                    125|                                                                   84|                                                                        44|                                                    -8|                                                                          12|                                                                78|                              217|                                                                1|                                                                       45|                                                           72|
# |OMG (feat. will.i...|              Usher|           atl hip hop|      2010|                                    130|                                                                   75|                                                                        78|                                                    -6|                                                                          36|                                                                33|                              269|                                                               20|                                                                        3|                                                           72|
# |        Eenie Meenie|      Sean Kingston|             dance pop|      2010|                                    121|                                                                   61|                                                                        72|                                                    -4|                                                                          11|                                                                83|                              202|                                                                5|                                                                        3|                                                           71|
# |The Time (Dirty Bit)|The Black Eyed Peas|             dance pop|      2010|                                    128|                                                                   81|                                                                        82|                                                    -8|                                                                          60|                                                                44|                              308|                                                                7|                                                                        7|                                                           70|
# |           Alejandro|          Lady Gaga|             dance pop|      2010|                                     99|                                                                   80|                                                                        63|                                                    -7|                                                                          36|                                                                37|                              274|                                                                0|                                                                        5|                                                           69|
# |Your Love Is My Drug|              Kesha|             dance pop|      2010|                                    120|                                                                   61|                                                                        83|                                                    -4|                                                                           9|                                                                76|                              187|                                                                1|                                                                       10|                                                           69|
# +--------------------+-------------------+----------------------+----------+---------------------------------------+---------------------------------------------------------------------+--------------------------------------------------------------------------+------------------------------------------------------+----------------------------------------------------------------------------+------------------------------------------------------------------+---------------------------------+-----------------------------------------------------------------+-------------------------------------------------------------------------+-------------------------------------------------------------+
# only showing top 20 rows

# %%
#Renomeando colunas necessárias
dat_music = dat_music.withColumnRenamed("title","titulo") \
    .withColumnRenamed("artist","artista") \
.withColumnRenamed("the genre of the track","genero") \
.withColumnRenamed("year","ano") \
.withColumnRenamed("Beats.Per.Minute -The tempo of the song","BPM") \
.withColumnRenamed("Energy- The energy of a song - the higher the value the more energtic","energia") \
.withColumnRenamed("Danceability - The higher the value the easier it is to dance to this song","dancabilidade") \
.withColumnRenamed("Loudness/dB - The higher the value the louder the song","volume") \
.withColumnRenamed("Liveness - The higher the value the more likely the song is a live recording","liveness") \
.withColumnRenamed("Valence - The higher the value the more positive mood for the song","valencia") \
.withColumnRenamed("Length - The duration of the song","comprimento") \
.withColumnRenamed("Acousticness - The higher the value the more acoustic the song is","acustica") \
.withColumnRenamed("Speechiness - The higher the value the more spoken word the song contains","fala") \
.withColumnRenamed("Popularity- The higher the value the more popular the song is","popularidade") 

dat_music.printSchema()
# Out:
# root
#  |-- titulo: string (nullable = true)
#  |-- artista: string (nullable = true)
#  |-- genero: string (nullable = true)
#  |-- ano: string (nullable = true)
#  |-- BPM: string (nullable = true)
#  |-- energia: integer (nullable = true)
#  |-- dancabilidade: integer (nullable = true)
#  |-- volume: integer (nullable = true)
#  |-- liveness: integer (nullable = true)
#  |-- valencia: integer (nullable = true)
#  |-- comprimento: integer (nullable = true)
#  |-- acustica: integer (nullable = true)
#  |-- fala: integer (nullable = true)
#  |-- popularidade: integer (nullable = true)

# %%
#Excluindo colunas nao utilizadas
dat_music = dat_music.drop("volume", "liveness","acustica","fala","comprimento")

#Adicionando coluna ‘Id_music’ no dataset de musicas
windowSpec = Window.orderBy("titulo")
dat_music = dat_music.withColumn("id_music", F.row_number().over(windowSpec))

dat_music.show()
# Out:
# +--------------------+---------------+----------------+----+---+-------+-------------+--------+------------+--------+
# |              titulo|        artista|          genero| ano|BPM|energia|dancabilidade|valencia|popularidade|id_music|
# +--------------------+---------------+----------------+----+---+-------+-------------+--------+------------+--------+
# |...Ready For It? ...|   Taylor Swift|             pop|2018|160|     84|           58|      50|          52|       1|
# |                 1+1|        Beyonce|       dance pop|2011| 63|     38|           30|      26|          60|       2|
# |           24K Magic|     Bruno Mars|             pop|2017|107|     80|           82|      63|          69|       3|
# |2U (feat. Justin ...|   David Guetta|       dance pop|2018|145|     61|           53|      53|          65|       4|
# |                   3| Britney Spears|       dance pop|2010|135|     71|           70|      79|          62|       5|
# |               43776|        Beyonce|       dance pop|2015|136|     71|           75|      56|          72|       6|
# |             7 Years|   Lukas Graham|      danish pop|2016|120|     47|           77|      34|          80|       7|
# |         A L I E N S|       Coldplay|  permanent wave|2017|148|     88|           43|      25|          41|       8|
# |A Little Party Ne...|         Fergie|       dance pop|2013|130|     62|           76|      52|          65|       9|
# |A Little Party Ne...|         Fergie|       dance pop|2014|130|     62|           76|      52|          65|      10|
# | A Sky Full of Stars|       Coldplay|  permanent wave|2014|125|     68|           55|      16|          60|      11|
# |    A Thousand Years|Christina Perri|       dance pop|2011|139|     41|           42|      16|          81|      12|
# |           Adore You|    Miley Cyrus|       dance pop|2014|120|     66|           58|      20|          72|      13|
# |     Ain't Your Mama| Jennifer Lopez|       dance pop|2016|120|     68|           76|      82|          72|      14|
# |           Alejandro|      Lady Gaga|       dance pop|2010| 99|     80|           63|      37|          69|      15|
# |               Alive|            Sia|australian dance|2015|100|     76|           51|      44|          61|      16|
# | All About That Bass| Meghan Trainor|       dance pop|2015|134|     88|           81|      96|          65|      17|
# |All Around The Wo...|          R3HAB|        big room|2019|125|     86|           73|      52|          82|      18|
# |           All I Ask|          Adele|    british soul|2016|142|     28|           59|      34|          71|      19|
# |           All I Ask|          Adele|    british soul|2017|142|     28|           59|      34|          71|      20|
# +--------------------+---------------+----------------+----+---+-------+-------------+--------+------------+--------+
# only showing top 20 rows

# %%
#Gerar o csv antes de inserir no couch
# dat_music.coalesce(1).write.csv(
#         path='B:\Faculdade\PMD\musicWithIds',
#         mode="overwrite",
#         header=True,
#         sep=",")

datpandas = dat_music.toPandas().to_csv('B:\Faculdade\PMD\musicWithIds\music.csv', sep=',', encoding='utf-8', index = False)

# %%
#Conexão com Couchdb
import csv
import couchdb 

couch = couchdb.Server('http://admin:123456789@127.0.0.1:5984')

dbname = "musicas" #Nome do banco

# %%
#Criação do Banco de Dados e Inserção dos dados da fonte
try:
    db = couch[dbname]
except:
    db = couch.create(dbname)
    with open(r'B:\Faculdade\PMD\musicWithIds\music.csv', encoding="utf-8") as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        keys = next(csv_reader)
        line_count = 0
        for values in csv_reader:
            values[3] = int(values[3])if values[3].isdigit() else 0
            values[4] = int(values[4])if values[4].isdigit() else 0
            values[5] = int(values[5])if values[5].isdigit() else 0
            values[6] = int(values[6])if values[6].isdigit() else 0
            values[7] = int(values[7])if values[7].isdigit() else 0
            values[8] = int(values[8])if values[8].isdigit() else 0
            db.save(dict(zip(keys, values)))

# %%
#Preparando os Nodes para o Neo4j
dat_music4j = dat_music.select(dat_music["id_music"], dat_music["titulo"])

dat_usuarios = dat_usuarios.withColumn("most_list", split(col("music_fav"), ",").getItem(0))
dat_usuarios4j = dat_usuarios.select(dat_usuarios["id_person"], dat_usuarios["nome"],dat_usuarios["most_list"] )

# %%
#Preparando os Relationships para o Neo4j
columnsPerson = ["id_person", "id_amigo"]
columnsMusic = ["id_person", "id_music"]
arrPerson = []
arrMusic = []
dat_usu_amigo = spark.sparkContext.emptyRDD()
for row in dat_usuarios.collect():
    vetAmigos = row["amigos"].split(",")
    vetMusics = row["music_fav"].split(",")
    
    for amigo in vetAmigos:
        arrPerson.append((row["id_person"],int(amigo)))
        
    for music in vetMusics:
        arrMusic.append((row["id_person"],int(music)))  
    
        
usu_amigo = spark.createDataFrame(arrPerson, columnsPerson)
usu_music = spark.createDataFrame(arrMusic, columnsMusic)


usu_amigo.show();
usu_music.show();
# Out:
# +---------+--------+
# |id_person|id_amigo|
# +---------+--------+
# |        1|    1369|
# |        1|    1744|
# |        1|     406|
# |        1|     223|
# |        2|     845|
# |        2|    1134|
# |        2|    1933|
# |        2|     823|
# |        3|     352|
# |        3|     528|
# |        3|     998|
# |        3|     976|
# |        4|     736|
# |        4|    1172|
# |        4|    1584|
# |        4|     443|
# |        5|    1783|
# |        5|    1497|
# |        5|    1915|
# |        5|     425|
# +---------+--------+
# only showing top 20 rows
#
# +---------+--------+
# |id_person|id_music|
# +---------+--------+
# |        1|     404|
# |        1|     123|
# |        1|     586|
# |        2|     384|
# |        2|      41|
# |        2|     550|
# |        3|      52|
# |        3|     391|
# |        3|      39|
# |        4|     368|
# |        4|     155|
# |        4|      76|
# |        5|     536|
# |        5|     590|
# |        5|     507|
# |        6|      67|
# |        6|     159|
# |        6|     221|
# |        7|     395|
# |        7|      22|
# +---------+--------+
# only showing top 20 rows

# %%
#Escrevendo usuários no neo4j
dw_usuarios = (dat_usuarios4j.write\
.format("org.neo4j.spark.DataSource")\
.mode("Overwrite")\
.option("url", "neo4j://localhost:7687")\
.option("authentication.basic.username", "neo")\
.option("authentication.basic.password", "1234")\
.option("labels", ":Person")\
.option("node.keys", "id_person")\
.save())

# %%
#Escrevendo músicas no neo4j
dw_musics = (dat_music4j.write\
.format("org.neo4j.spark.DataSource")\
.mode("Overwrite")\
.option("url", "neo4j://localhost:7687")\
.option("authentication.basic.username", "neo")\
.option("authentication.basic.password", "1234")\
.option("labels", ":Music")\
.option("node.keys", "id_music")\
.save())

# %%
#Fazendo as relações de amigos
usu_amigo.write\
.format("org.neo4j.spark.DataSource")\
.mode("Overwrite")\
.option("url", "neo4j://localhost:7687")\
.option("authentication.type","basic")\
.option("authentication.basic.username", "neo")\
.option("authentication.basic.password", "1234")\
.option("relationship", "amigo_de")\
.option("relationship.save.strategy", "keys")\
.option("relationship.source.labels", ":Person")\
.option("relationship.source.node.keys", "id_person:id_person")\
.option("relationship.target.labels", ":Person")\
.option("relationship.target.node.keys", "id_amigo:id_person")\
.save()

# %%
#Fazendo as relações de musicas favoritas
usu_music.write\
.format("org.neo4j.spark.DataSource")\
.mode("Overwrite")\
.option("url", "neo4j://localhost:7687")\
.option("authentication.type","basic")\
.option("authentication.basic.username", "neo")\
.option("authentication.basic.password", "1234")\
.option("relationship", "music_fav")\
.option("relationship.save.strategy", "keys")\
.option("relationship.source.labels", ":Person")\
.option("relationship.source.node.keys", "id_person:id_person")\
.option("relationship.target.labels", ":Music")\
.option("relationship.target.node.keys", "id_music:id_music")\
.save()

# %%
#Consulta 1 - Retornar as músicas que tenham valores próximos de BPM, energia, dançabilidade e valência da música favorita do usuário.(Documentos)
idClientC1 = '1534'
allDocs =[]

#grafo
c1_mIds = spark.read\
.format("org.neo4j.spark.DataSource")\
.option("url", "neo4j://localhost:7687")\
.option("authentication.type","basic")\
.option("authentication.basic.username", "neo")\
.option("authentication.basic.password", "1234")\
.option("query","MATCH (p:Person) WHERE p.id_person = " + idClientC1 + " RETURN p.most_list")\
.load()

#Musica favorita do cliente
for doc in db.find({
   'selector': { 
        "id_music": {
            "$eq": c1_mIds.collect()[0][0]
        }
    },
    "fields": ["BPM", "energia", "dancabilidade", "valencia","titulo", "id_music"] 
    }):
    fav = doc

print(fav["BPM"], fav["energia"], fav["dancabilidade"], fav["valencia"], fav["titulo"], "\n\n\n")

#Consulta baseada no intervalo
for doc in db.find({
   "selector": {
      "$and": [
         {
            "BPM": {
               "$and": [
                  {
                     "$gte": int(fav["BPM"]) - 8
                  },
                  {
                     "$lte": int(fav["BPM"]) + 8
                  }
               ]
            }
         },
         {
            "energia": {
                "$and": [
                  {
                     "$gte": int(fav["energia"]) - 6
                  },
                  {
                     "$lte": int(fav["energia"]) + 6
                  }
               ]
            }
         },
         {
            "dancabilidade": {
                "$and": [
                  {
                     "$gte": int(fav["dancabilidade"]) - 6
                  },
                  {
                     "$lte": int(fav["dancabilidade"]) + 6
                  }
               ]
            }
         },
         {
            "valencia": {
                "$and": [
                  {
                     "$gte": int(fav["valencia"]) - 8
                  },
                  {
                     "$lte": int(fav["valencia"]) + 8
                  }
               ]
            }
         }
      ]
   },
    "limit": 200
    
}):
    print(doc["BPM"], doc["energia"], doc["dancabilidade"], doc["valencia"], doc["titulo"])
# Out:
# 125 94 60 55 We Are One (Ole Ola) [The Official 2014 FIFA World Cup Song]
#
#
#
# 118 88 65 49 Best Song Ever
# 131 93 66 53 Judas
# 128 93 57 58 Sweet Nothing (feat. Florence Welch)
# 124 93 63 47 This Is What You Came For
# 126 92 54 51 Under Control
# 125 94 60 55 We Are One (Ole Ola) [The Official 2014 FIFA World Cup Song]

# %%
#Consulta 2 - Retornar as músicas agrupadas pelos gêneros das músicas favoritas do usuário ordenadas por ano.(Documentos)
idClientC2 = '657'
musicsFav = []
musicsgens = []

#Busca as músicas favorita do cliente
c1_mIds = spark.read\
.format("org.neo4j.spark.DataSource")\
.option("url", "neo4j://localhost:7687")\
.option("authentication.type","basic")\
.option("authentication.basic.username", "neo")\
.option("authentication.basic.password", "1234")\
.option("query","MATCH (p:Person) - [re:music_fav] -> (m:Music) WHERE p.id_person =" + idClientC2 + " RETURN m.id_music")\
.load()

for item in c1_mIds.collect():
    musicsFav.append(str(item[0]))
    
print(musicsFav)
#Genero da musica favorita do cliente
for doc in db.find({
   "selector": {
      "id_music": {
         "$or": musicsFav
      }
   },
    "sort": [{"ano":"asc"}]
    }):
    musicsgens.append(doc["genero"])
print(musicsgens)
for doc in db.find({
   "selector": {
      "$or": [
         {
            "genero": {
               "$or": musicsgens
            }
         }
      ]
   },
   "sort": [
        {
            "genero": "asc"
        },
        {
             "ano": "asc"
        }
   ],
    "limit": 603
    }):
    print(doc["genero"], doc["ano"])
# Out:
# ['577', '480', '8']
# ['art pop', 'permanent wave', 'dance pop']
# art pop 2010
# art pop 2013
# art pop 2014
# art pop 2015
# art pop 2016
# art pop 2017
# art pop 2017
# art pop 2017
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2010
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2011
# dance pop 2012
# dance pop 2012
# dance pop 2012
# dance pop 2012
# dance pop 2012
# dance pop 2012
# dance pop 2012
# dance pop 2012
# dance pop 2012
# dance pop 2012
# dance pop 2012
# dance pop 2012
# dance pop 2012
# dance pop 2012
# dance pop 2012
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2013
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2014
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2015
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2016
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2017
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2018
# dance pop 2019
# dance pop 2019
# dance pop 2019
# dance pop 2019
# dance pop 2019
# dance pop 2019
# permanent wave 2012
# permanent wave 2013
# permanent wave 2014
# permanent wave 2017

# %%
#Consulta 3 - Retornar uma playlist com músicas de pessoas que compartilhem a mesma música favorita, percorrendo cinco níveis de profundidade. (Grafo + Documento)
idClientC3 = '45'
allIds =[]

c3_mIds = spark.read\
.format("org.neo4j.spark.DataSource")\
.option("url", "neo4j://localhost:7687")\
.option("authentication.type","basic")\
.option("authentication.basic.username", "neo")\
.option("authentication.basic.password", "1234")\
.option("query","MATCH (p:Person) - [fav:music_fav] -> (m:Music) <- [mu:music_fav*1..5] - (p2:Person) - [mu2:music_fav] -> (demais_music:Music) WHERE m.id_music = toInteger(p.most_list) AND p.id_person = "+ idClientC3+" AND demais_music.id_music = toInteger(p2.most_list) AND p.id_person <> p2.id_person RETURN demais_music.id_music")\
.load()


for idmusic in c3_mIds.collect():
    allIds.append(str(idmusic[0]))
    
    
for doc in db.find({
   "selector": {
      "id_music": {
         "$or": allIds
      }
   },
    "limit": 200
    }):
    print(doc["titulo"], doc["artista"], doc["genero"], doc["ano"])
# Out:
# Doesn't Mean Anything Alicia Keys hip pop 2010
# Dog Days Are Over Florence + The Machine art pop 2010
# End Game Taylor Swift pop 2018
# I Wanna Go Britney Spears dance pop 2011
# Impossible James Arthur pop 2013
# Rise Katy Perry dance pop 2016
# Sparks Hilary Duff dance pop 2015
# Want To Dua Lipa dance pop 2018

# %%
#Consulta 4 - Retornar uma playlist levando em consideração as músicas favoritas de amigos em até três níveis de profundidade, ordenada pela popularidade. (Grafo + Documento)
idClientC4 = '865'
allIds =[]

c4_mIds = spark.read\
.format("org.neo4j.spark.DataSource")\
.option("url", "neo4j://localhost:7687")\
.option("authentication.type","basic")\
.option("authentication.basic.username", "neo")\
.option("authentication.basic.password", "1234")\
.option("query","MATCH (p:Person) - [am:amigo_de*1..3] -> (p2:Person) - [mu:music_fav] -> (p2mu:Music) \
        WHERE p.id_person = "+idClientC4+"\
        RETURN p2mu.id_music")\
.load()

for idmusic in c4_mIds.collect():
    allIds.append(str(idmusic[0]))
    
for doc in db.find({
   "selector": {
      "id_music": {
         "$or": allIds
      }
   },
    "limit": 200
    }):
    print(doc["titulo"], doc["artista"], doc["genero"], doc["ano"])
# Out:
# 3 Britney Spears dance pop 2010
# Alejandro Lady Gaga dance pop 2010
# All I Ask Adele british soul 2016
# All I Ask Adele british soul 2017
# All The Right Moves OneRepublic dance pop 2010
# All We Know The Chainsmokers electropop 2016
# All of Me John Legend neo mellow 2014
# Angel Fifth Harmony dance pop 2017
# Anything Could Happen Ellie Goulding dance pop 2013
# Atlas - From 揟he Hunger Games: Catching Fire?Soundtrack Coldplay permanent wave 2013
# Attention Charlie Puth dance pop 2018
# BURNITUP Janet Jackson dance pop 2016
# Bad Liar Selena Gomez dance pop 2018
# Bad Romance Lady Gaga dance pop 2010
# Bang Bang Jessie J australian pop 2015
# Beauty And A Beat Justin Bieber canadian pop 2012
# Beneath Your Beautiful Labrinth pop 2013
# Best Thing I Never Had Beyonce dance pop 2011
# Blow Me (One Last Kiss) Pink dance pop 2012
# Bodak Yellow Cardi B pop 2017
# Body Moves DNCE dance pop 2017
# Body Say Demi Lovato dance pop 2016
# Bon app閠it Katy Perry dance pop 2017
# Boom Boom RedOne moroccan pop 2018
# Break Free Ariana Grande dance pop 2015
# Break Your Heart Taio Cruz dance pop 2010
# Broken Arrows Avicii big room 2015
# Can't Hold Us (feat. Ray Dalton) Macklemore & Ryan Lewis dance pop 2013
# Can't Remember to Forget You (feat. Rihanna) Shakira colombian pop 2014
# Capital Letters Hailee Steinfeld dance pop 2018
# Chandelier Sia australian dance 2014
# Clarity Zedd complextro 2013
# Close Nick Jonas dance pop 2016
# Closer The Chainsmokers electropop 2017
# Clown Emeli Sande dance pop 2013
# Cold (feat. Future) Maroon 5 pop 2017
# Company Justin Bieber canadian pop 2015
# Company Justin Bieber canadian pop 2016
# Cooler Than Me - Single Mix Mike Posner dance pop 2010
# Crazy Kids (feat. will.i.am) Kesha dance pop 2013
# Cross Me (feat. Chance the Rapper & PnB Rock) Ed Sheeran pop 2019
# DJ Got Us Fallin' In Love (feat. Pitbull) Usher atl hip hop 2010
# Desire Years & Years dance pop 2016
# Diamonds Rihanna barbadian pop 2012
# Doesn't Mean Anything Alicia Keys hip pop 2010
# Don't Ed Sheeran pop 2015
# Dynamite Taio Cruz dance pop 2010
# Eenie Meenie Sean Kingston dance pop 2010
# Elastic Heart Sia australian dance 2015
# Electricity (with Dua Lipa) Silk City edm 2018
# Feel The Light - From The Home Soundtrack Jennifer Lopez dance pop 2015
# Fireball (feat. John Ryan) Pitbull dance pop 2015
# First Time Kygo edm 2017
# First Time Kygo edm 2018
# Free Me Sia australian dance 2017
# G.U.Y. Lady Gaga dance pop 2014
# Genie In a Bottle Christina Aguilera dance pop 2015
# Get Low (with Liam Payne) Zedd complextro 2017
# Get Lucky (feat. Pharrell Williams & Nile Rodgers) - Radio Edit Daft Punk electro 2013
# Girls (feat. Cardi B  Bebe Rexha & Charli XCX) Rita Ora 0
# Glad You Came The Wanted boy band 2012
# Good Time Owl City pop 2012
# Good as Hell (feat. Ariana Grande) - Remix Lizzo escape room 2019
# Greenlight (feat. Flo Rida & LunchMoney Lewis) Pitbull dance pop 2017
# Hands To Myself Selena Gomez dance pop 2016
# Happier Marshmello brostep 2019
# Hard Rihanna barbadian pop 2010
# Heartbeat Song Kelly Clarkson dance pop 2015
# Heartbreaker Justin Bieber canadian pop 2013
# Hello Martin Solveig big room 2010
# Hello Adele british soul 2015
# Here Alessia Cara canadian contemporary r&b 2015
# Higher Love Kygo edm 2019
# Him & I (with Halsey) G-Eazy hip hop 2018
# Hold It Against Me Britney Spears dance pop 2011
# I Don't Care (with Justin Bieber) Ed Sheeran pop 2019
# I Don抰 Wanna Live Forever (Fifty Shades Darker) ZAYN dance pop 2017
# I Feel It Coming The Weeknd canadian contemporary r&b 2017
# I Got You Bebe Rexha dance pop 2016
# I Really Like You Carly Rae Jepsen canadian pop 2015
# I Took A Pill In Ibiza - Seeb Remix Mike Posner dance pop 2016
# I Wanna Go Britney Spears dance pop 2011
# I'm Into You Jennifer Lopez dance pop 2011
# I'm Not The Only One Sam Smith pop 2015
# If I Lose Myself - Alesso vs OneRepublic OneRepublic dance pop 2013
# Impossible James Arthur pop 2013
# Into You Ariana Grande dance pop 2016
# Invading My Mind Jennifer Lopez dance pop 2011
# It Ain't Me (with Selena Gomez) Kygo edm 2017
# It Will Rain Bruno Mars pop 2012
# Jealous - Remix Nick Jonas dance pop 2015
# Just Give Me a Reason (feat. Nate Ruess) Pink dance pop 2013
# Just Like Fire (From the Original Motion Picture Alice Through The Looking Glass) Pink dance pop 2016
# Just the Way You Are Bruno Mars pop 2011
# Keeping Your Head Up Birdy neo mellow 2016
# Kissing Strangers DNCE dance pop 2018
# Lay It All on Me Rudimental dance pop 2015
# Lemon N.E.R.D hip hop 2018
# Like A G6 Far East Movement dance pop 2010
# Live It Up Jennifer Lopez dance pop 2013
# Lose You To Love Me Selena Gomez dance pop 2019
# Love Me Like You Little Mix dance pop 2015
# Love Never Felt So Good Michael Jackson pop 2014
# Love On The Brain Rihanna barbadian pop 2018
# Love Somebody Maroon 5 pop 2013
# Make Me Like You Gwen Stefani dance pop 2016
# Memories Maroon 5 pop 2019
# Messin' Around Pitbull dance pop 2017
# Misery Maroon 5 pop 2010
# Miss You (with Major Lazer & Tory Lanez) Cashmere Cat downtempo 2018
# Moment 4 Life - Album Version (Edited) Nicki Minaj dance pop 2011
# Monster Kanye West chicago rap 2011
# Moves Like Jagger - Studio Recording From The Voice Performance Maroon 5 pop 2011
# Mr. Put It Down Ricky Martin dance pop 2015
# My House Flo Rida dance pop 2015
# My Way Calvin Harris dance pop 2017
# NO Meghan Trainor dance pop 2016
# Naturally Selena Gomez & The Scene dance pop 2010
# New Rules Dua Lipa dance pop 2018
# No Vacancy (with Sebasti醤 Yatra) OneRepublic dance pop 2017
# Not Myself Tonight Christina Aguilera dance pop 2010
# OMG (feat. will.i.am) Usher atl hip hop 2010
# On The Floor Jennifer Lopez dance pop 2011
# One Call Away (feat. Tyga) - Remix Charlie Puth dance pop 2016
# Out Of The Woods Taylor Swift pop 2016
# Paris The Chainsmokers electropop 2017
# Party Rock Anthem LMFAO dance pop 2011
# Perfect Duet (Ed Sheeran & Beyonc? Ed Sheeran pop 2018
# Pom Poms Jonas Brothers boy band 2013
# Price Tag Jessie J australian pop 2011
# Problem Ariana Grande dance pop 2014
# Rather Be (feat. Jess Glynne) Clean Bandit dance pop 2015
# Reality (feat. Janieck Devy) - Radio Edit Lost Frequencies belgian edm 2017
# Reality - Radio Edit Lost Frequencies belgian edm 2015
# Rich Boy Galantis big room 2017
# Rise Katy Perry dance pop 2016
# Rude MAGIC pop 2014
# Run Away With Me Carly Rae Jepsen canadian pop 2016
# Run the World (Girls) Beyonce dance pop 2011
# Runnin' (Lose It All) Naughty Boy tropical house 2015
# Runnin' (Lose It All) Naughty Boy tropical house 2016
# SELFIE The Chainsmokers electropop 2014
# Say Something Justin Timberlake dance pop 2018
# Scars To Your Beautiful Alessia Cara canadian contemporary r&b 2016
# Secrets OneRepublic dance pop 2010
# Send My Love (To Your New Lover) Adele british soul 2016
# Sexy And I Know It LMFAO dance pop 2011
# Sexy Bitch (feat. Akon) David Guetta dance pop 2010
# She Looks So Perfect 5 Seconds of Summer boy band 2014
# Sign of the Times Harry Styles dance pop 2018
# Slide (feat. Frank Ocean & Migos) Calvin Harris dance pop 2017
# Someone You Loved Lewis Capaldi pop 2019
# Sorry Justin Bieber canadian pop 2015
# South of the Border (feat. Camila Cabello & Cardi B) Ed Sheeran pop 2019
# Sparks Hilary Duff dance pop 2015
# St Jude Florence + The Machine art pop 2015
# Starboy The Weeknd canadian contemporary r&b 2017
# Starving Hailee Steinfeld dance pop 2016
# Stay The Night - Featuring Hayley Williams Of Paramore Zedd complextro 2014
# Stereo Hearts (feat. Adam Levine) Gym Class Heroes dance pop 2012
# Summer Bummer (feat. ASAP Rocky & Playboi Carti) Lana Del Rey art pop 2017
# Summertime Sadness (Lana Del Rey Vs. Cedric Gervais) - Cedric Gervais Remix Lana Del Rey art pop 2013
# Supplies Justin Timberlake dance pop 2018
# Swish Swish Katy Perry dance pop 2017
# TKO Justin Timberlake dance pop 2013
# Take It Off Kesha dance pop 2010
# Talk Dirty (feat. 2 Chainz) Jason Derulo dance pop 2014
# Tell Me You Love Me - NOTD Remix Demi Lovato dance pop 2018
# Tequila Dan + Shay contemporary country 2018
# The Edge Of Glory Lady Gaga dance pop 2011
# The Greatest Sia australian dance 2017
# The Hills The Weeknd canadian contemporary r&b 2016
# These Days Rudimental dance pop 2018
# Thinking out Loud Ed Sheeran pop 2015
# This Town Niall Horan dance pop 2018
# TiK ToK Kesha dance pop 2010
# Tired Alan Walker electro house 2017
# Tonight (I'm Fuckin' You) Enrique Iglesias dance pop 2011
# Tonight Tonight Hot Chelle Rae dance pop 2011
# Too Good Drake canadian hip hop 2016
# Touch (feat. Kid Ink) Little Mix dance pop 2017
# Treat You Better Shawn Mendes canadian pop 2017
# Truth Hurts Lizzo escape room 2019
# Try Sleeping with a Broken Heart Alicia Keys hip pop 2010
# Turning Page Sleeping At Last acoustic pop 2011
# Underneath the Tree Kelly Clarkson dance pop 2013
# Wait Maroon 5 pop 2018
# Wake Me Up Avicii big room 2013
# Walks Like Rihanna The Wanted boy band 2013
# We Are Never Ever Getting Back Together Taylor Swift pop 2012
# We Are One (Ole Ola) [The Official 2014 FIFA World Cup Song] Pitbull dance pop 2014
# We Own The Night The Wanted boy band 2013
# We R Who We R Kesha dance pop 2011
# What About Us Pink dance pop 2018
# What the Hell Avril Lavigne canadian pop 2011
# What's My Name? Rihanna barbadian pop 2011
# When We Were Young Adele british soul 2016
# Wiggle (feat. Snoop Dogg) Jason Derulo dance pop 2014
# Wild Thoughts (feat. Rihanna & Bryson Tiller) DJ Khaled dance pop 2018
# Work from Home (feat. Ty Dolla Sign) Fifth Harmony dance pop 2016
